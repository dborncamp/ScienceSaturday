# %% [markdown]
# # Notebook For Cleaning The Data
# This is a notebook I use for cleaning the data that came out of the google sheets https://docs.google.com/spreadsheets/d/1clTSVXBHpFB_4yqkAQhzvsDoVax4SZUYpGdbCy7FZ6U/edit#gid=329859720

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Start with the Beer results

# %%
df = pd.read_excel("../data/results.xlsx",sheet_name=1)

# %%
df
# Out:
#                  Beer Letter  Ali Alec  \
# Budweiser                  A    3    4
# PBR                       B     2    3
# Ichiban                    C    2    1
# Miller High Life           D    1    1
# Dos Equis                  E    2    1
# Yuengling                  F    4    5
# Natural Light              G    3    1
# Budlight                   H    1    2
# Coors (Banquet)            I    2    3
# Red Stripe                 J    1    3
# Corona                     K    3    1
# Modelo                     L    1    1
# Narragansett               M    3    4
# Miller Lite                N    1    1
# Natty Boh                  O    3    1
# Rolling Rock               P    3    2
# Coors Light                Q    2    2
# Heineken                   R    2    4
# Beer Order               NaN  NaN  NaN
# NaN                      NaN    A    P
# NaN                      NaN    F    D
# NaN                      NaN    E    I
# NaN                      NaN    H    G
# ...

# %%
beerScores = df.iloc[0:18]

# %%
beerOrder = df.iloc[19:37]

# %%
beerNotes = df.iloc[38:57]

# %% [markdown]
# ### got the data
# Now save the Data Frames as a good CSV

# %%
beerScores.to_csv("../data/SS2_beerScores.csv")
beerOrder.to_csv("../data/beerOrder.csv")
beerNotes.to_csv("../data/beerNotes.csv")

# %% [markdown]
# ## Now do the Wine

# %%
winedf = pd.read_excel("../data/results.xlsx",sheet_name=3)

# %%
winedf
# Out:
#                              Dave Heather    Jon  Katie Matt G  Blair   Mike  \
# Case1       Response 1 (6)  White   White   Rose  White    Red  White  White
# 6 vs 1      Rating 1            3       2      3      5      3      2      3
# Group 1     Actual Color 1  White   White  White  White  White  White  White
# NaN         NaN                 1       1      0      1      0      1      1
#             Response 2 (1)    Red     Red    Red    Red  White    Red    Red
#             Rating 2            4       3      2      3      2      3      2
#             Actual Color 2    Red     Red    Red    Red    Red    Red    Red
#             NaN                 1       1      1      1      0      1      1
# Case2       Response 1 (4)  White     Red  White  White    Red  White  White
# 4 vs 6      Rating 1            1       1      2      4      3      2      3
# NaN         Actual Color 1  White   White  White  White  White  White  White
# ...

# %%
# Out:
# Empty DataFrame
# Columns: [Dave, Heather, Jon, Katie, Matt G, Blair, Mike, Roberto, Unnamed: 8, Unnamed: 9, Unnamed: 10, Matt B, Miranda, Sean, Jenna, Rachel, Jules, Matt D., Jo]
# Index: []

# %% [markdown]
# Damn it....
# Oh well at least there is the beer even after I murdered Rachel's spreadsheet..
