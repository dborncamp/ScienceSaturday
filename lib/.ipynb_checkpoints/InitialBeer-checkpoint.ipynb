# %% [markdown]
# # Look At Initial Beer things

# %%
import pandas as pd
import seaborn as sns
# %matplotlib inline
sns.set(rc={'figure.figsize':(10,8)})

# %%
scoresdf = pd.read_csv("../data/beerScores.csv")

# %%
scoresdf.head()
# Out:
#                Beer Beer Letter  Ali  Alec  Cara  Claire  Dave  Elaine  Emily  \
# 0         Budweiser           A    3     4     2     4.1     2     3.5    4.0
# 1               PBR          B     2     3     4     3.0     3     2.0    2.0
# 2           Ichiban           C    2     1     4     1.8     2     1.0    1.0
# 3  Miller High Life           D    1     1     3     2.5     2     2.5    3.0
# 4         Dos Equis           E    2     1     5     3.8     4     1.5    3.5
#
#    Heather  Jenna    Jo  Joe  Jon  Jules  Matt D  Miranda  Rachel  Roberto  \
# 0        3    3.5  2.50    3    3    1.3     3.0      3.5       2      2.0
# 1        2    3.0  2.75    3    2    4.5     1.0      2.0       1      3.0
# 2        2    3.0  2.00    2    1    3.0     3.5      3.0       2      1.0
# 3        2    3.0  3.00    4    3    3.5     2.0      4.0       3      4.0
# 4        4    4.0  4.00    2    2    4.8     3.0      4.0       2      4.5
#
#    Tyler
# 0    4.0
# 1    3.5
# 2    1.8
# 3    4.0
# 4    4.5

# %%
scoresdf.T
# Out:
#                     0     1        2                 3          4          5   \
# Beer         Budweiser   PBR  Ichiban  Miller High Life  Dos Equis  Yuengling
# Beer Letter          A    B         C                 D          E          F
# Ali                  3     2        2                 1          2          4
# Alec                 4     3        1                 1          1          5
# Cara                 2     4        4                 3          5          4
# Claire             4.1     3      1.8               2.5        3.8          1
# Dave                 2     3        2                 2          4          4
# Elaine             3.5     2        1               2.5        1.5          4
# Emily                4     2        1                 3        3.5        3.5
# Heather              3     2        2                 2          4          5
# Jenna              3.5     3        3                 3          4          2
# Jo                 2.5  2.75        2                 3          4        4.7
# Joe                  3     3        2                 4          2          4
# Jon                  3     2        1                 3          2          4
# Jules              1.3   4.5        3               3.5        4.8          5
# Matt D               3     1      3.5                 2          3          3
# Miranda            3.5     2        3                 4          4        4.5
# Rachel               2     1        2                 3          2          4
# Roberto              2     3        1                 4        4.5        2.5
# Tyler                4   3.5      1.8                 4        4.5        4.8
#
#                         6         7                8           9       10  \
# Beer         Natural Light  Budlight  Coors (Banquet)  Red Stripe  Corona
# Beer Letter              G         H                I           J       K
# Ali                      3         1                2           1       3
# Alec                     1         2                3           3       1
# Cara                     2         2                2           1       2
# Claire                 2.2       3.8              3.8         2.4       3
# Dave                     3         1                3           2       1
# Elaine                   3         2                4           1     1.5
# Emily                    3         3                4           1     1.5
# Heather                  2         3                2           3       1
# Jenna                  1.5         2                3         1.5       1
# Jo                       2         3              2.5           3     1.5
# Joe                      2         4                3           3       1
# Jon                      3         4                2           2       1
# Jules                  3.5         2              1.5           3       1
# Matt D                   2         2              3.5           1       1
# Miranda                  3         3              3.5           1       1
# Rachel                   3         3                4           1       1
# Roberto                2.5       3.5              3.5           1       3
# Tyler                    2       4.5              3.5         4.9       1
#
#                  11            12           13         14            15  \
# Beer         Modelo  Narragansett  Miller Lite  Natty Boh  Rolling Rock
# Beer Letter       L             M            N          O             P
# Ali               1             3            1          3             3
# Alec              1             4            1          1             2
# Cara              1             4            2          3             2
# Claire          2.2           3.7          3.1        2.5             4
# Dave              2             4            3          3             3
# Elaine            3           1.5            2          2             3
# Emily             2           2.5            3        3.5             3
# Heather           1             5            3          2             4
# Jenna           2.5           3.5            2          3           2.5
# Jo                2             1          3.5        2.5           3.5
# Joe               2             3            1          1             4
# Jon               2             2            3          2             3
# Jules             4             4          2.9          1             3
# Matt D            2           2.5            1          2           2.5
# Miranda           2             3          3.5          4             3
# Rachel            3             3            2          3             4
# Roberto           3           3.5          2.5          3             1
# Tyler           2.5             3          1.5          2             3
#
#                       16        17
# Beer         Coors Light  Heineken
# Beer Letter            Q         R
# Ali                    2         2
# Alec                   2         4
# Cara                   3         4
# Claire               4.3       1.1
# Dave                   2         2
# Elaine               3.5         2
# Emily                  3         2
# Heather                3         1
# Jenna                1.5       2.5
# Jo                   4.5      2.75
# Joe                    3         2
# Jon                    3         2
# Jules                3.5         4
# Matt D                 3         1
# Miranda                2         2
# Rachel                 3         3
# Roberto              1.5         1
# Tyler                  4         2

# %%
scoresdf.index
# Out:
# RangeIndex(start=0, stop=18, step=1)

# %%
sns.boxplot(data=scoresdf, figsize=(18, 10))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-203-c3b344b02868> in <module>()
# ----> 1 sns.boxplot(data=scoresdf,figsize=(18, 10))
#
# ~/miniconda3/envs/sciSaturday/lib/python3.6/site-packages/seaborn/categorical.py in boxplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, notch, ax, **kwargs)
#    2215     kwargs.update(dict(whis=whis, notch=notch))
#    2216
# -> 2217     plotter.plot(ax, kwargs)
#    2218     return ax
#    2219
#
# ~/miniconda3/envs/sciSaturday/lib/python3.6/site-packages/seaborn/categorical.py in plot(self, ax, boxplot_kws)
#     542     def plot(self, ax, boxplot_kws):
#     543         """Make the plot."""
# --> 544         self.draw_boxplot(ax, boxplot_kws)
#     545         self.annotate_axes(ax)
#     546         if self.orient == "h":
#
# ~/miniconda3/envs/sciSaturday/lib/python3.6/site-packages/seaborn/categorical.py in draw_boxplot(self, ax, kws)
#     479                                          positions=[i],
#     480                                          widths=self.width,
# --> 481                                          **kws)
#     482                 color = self.colors[i]
#     483                 self.restyle_boxplot(artist_dict, color, props)
#
# ~/miniconda3/envs/sciSaturday/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1853                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1854                         RuntimeWarning, stacklevel=2)
# -> 1855             return func(ax, *args, **kwargs)
#    1856
#    1857         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# TypeError: boxplot() got an unexpected keyword argument 'figsize'

# %% [markdown]
# Looks like some people had a very high scatter in ratings

# %% [markdown]
# How about for each beer?

# %%
scoresdf.set_index("Beer")
# Out:
#                  Beer Letter  Ali  Alec  Cara  Claire  Dave  Elaine  Emily  \
# Beer
# Budweiser                  A    3     4     2     4.1     2     3.5    4.0
# PBR                       B     2     3     4     3.0     3     2.0    2.0
# Ichiban                    C    2     1     4     1.8     2     1.0    1.0
# Miller High Life           D    1     1     3     2.5     2     2.5    3.0
# Dos Equis                  E    2     1     5     3.8     4     1.5    3.5
# Yuengling                  F    4     5     4     1.0     4     4.0    3.5
# Natural Light              G    3     1     2     2.2     3     3.0    3.0
# Budlight                   H    1     2     2     3.8     1     2.0    3.0
# Coors (Banquet)            I    2     3     2     3.8     3     4.0    4.0
# Red Stripe                 J    1     3     1     2.4     2     1.0    1.0
# Corona                     K    3     1     2     3.0     1     1.5    1.5
# Modelo                     L    1     1     1     2.2     2     3.0    2.0
# Narragansett               M    3     4     4     3.7     4     1.5    2.5
# Miller Lite                N    1     1     2     3.1     3     2.0    3.0
# Natty Boh                  O    3     1     3     2.5     3     2.0    3.5
# Rolling Rock               P    3     2     2     4.0     3     3.0    3.0
# Coors Light                Q    2     2     3     4.3     2     3.5    3.0
# Heineken                   R    2     4     4     1.1     2     2.0    2.0
#
#                   Heather  Jenna    Jo  Joe  Jon  Jules  Matt D  Miranda  \
# Beer
# Budweiser               3    3.5  2.50    3    3    1.3     3.0      3.5
# PBR                     2    3.0  2.75    3    2    4.5     1.0      2.0
# Ichiban                 2    3.0  2.00    2    1    3.0     3.5      3.0
# Miller High Life        2    3.0  3.00    4    3    3.5     2.0      4.0
# Dos Equis               4    4.0  4.00    2    2    4.8     3.0      4.0
# Yuengling               5    2.0  4.70    4    4    5.0     3.0      4.5
# Natural Light           2    1.5  2.00    2    3    3.5     2.0      3.0
# Budlight                3    2.0  3.00    4    4    2.0     2.0      3.0
# Coors (Banquet)         2    3.0  2.50    3    2    1.5     3.5      3.5
# Red Stripe              3    1.5  3.00    3    2    3.0     1.0      1.0
# Corona                  1    1.0  1.50    1    1    1.0     1.0      1.0
# Modelo                  1    2.5  2.00    2    2    4.0     2.0      2.0
# Narragansett            5    3.5  1.00    3    2    4.0     2.5      3.0
# Miller Lite             3    2.0  3.50    1    3    2.9     1.0      3.5
# Natty Boh               2    3.0  2.50    1    2    1.0     2.0      4.0
# Rolling Rock            4    2.5  3.50    4    3    3.0     2.5      3.0
# Coors Light             3    1.5  4.50    3    3    3.5     3.0      2.0
# Heineken                1    2.5  2.75    2    2    4.0     1.0      2.0
#
#                   Rachel  Roberto  Tyler
# Beer
# Budweiser              2      2.0    4.0
# PBR                    1      3.0    3.5
# Ichiban                2      1.0    1.8
# Miller High Life       3      4.0    4.0
# Dos Equis              2      4.5    4.5
# Yuengling              4      2.5    4.8
# Natural Light          3      2.5    2.0
# Budlight               3      3.5    4.5
# Coors (Banquet)        4      3.5    3.5
# Red Stripe             1      1.0    4.9
# Corona                 1      3.0    1.0
# Modelo                 3      3.0    2.5
# Narragansett           3      3.5    3.0
# Miller Lite            2      2.5    1.5
# Natty Boh              3      3.0    2.0
# Rolling Rock           4      1.0    3.0
# Coors Light            3      1.5    4.0
# Heineken               3      1.0    2.0

# %%
beer = scoresdf.set_index("Beer")

# %%
beer
# Out:
#                  Beer Letter  Ali  Alec  Cara  Claire  Dave  Elaine  Emily  \
# Beer
# Budweiser                  A    3     4     2     4.1     2     3.5    4.0
# PBR                       B     2     3     4     3.0     3     2.0    2.0
# Ichiban                    C    2     1     4     1.8     2     1.0    1.0
# Miller High Life           D    1     1     3     2.5     2     2.5    3.0
# Dos Equis                  E    2     1     5     3.8     4     1.5    3.5
# Yuengling                  F    4     5     4     1.0     4     4.0    3.5
# Natural Light              G    3     1     2     2.2     3     3.0    3.0
# Budlight                   H    1     2     2     3.8     1     2.0    3.0
# Coors (Banquet)            I    2     3     2     3.8     3     4.0    4.0
# Red Stripe                 J    1     3     1     2.4     2     1.0    1.0
# Corona                     K    3     1     2     3.0     1     1.5    1.5
# Modelo                     L    1     1     1     2.2     2     3.0    2.0
# Narragansett               M    3     4     4     3.7     4     1.5    2.5
# Miller Lite                N    1     1     2     3.1     3     2.0    3.0
# Natty Boh                  O    3     1     3     2.5     3     2.0    3.5
# Rolling Rock               P    3     2     2     4.0     3     3.0    3.0
# Coors Light                Q    2     2     3     4.3     2     3.5    3.0
# Heineken                   R    2     4     4     1.1     2     2.0    2.0
#
#                   Heather  Jenna    Jo  Joe  Jon  Jules  Matt D  Miranda  \
# Beer
# Budweiser               3    3.5  2.50    3    3    1.3     3.0      3.5
# PBR                     2    3.0  2.75    3    2    4.5     1.0      2.0
# Ichiban                 2    3.0  2.00    2    1    3.0     3.5      3.0
# Miller High Life        2    3.0  3.00    4    3    3.5     2.0      4.0
# Dos Equis               4    4.0  4.00    2    2    4.8     3.0      4.0
# Yuengling               5    2.0  4.70    4    4    5.0     3.0      4.5
# Natural Light           2    1.5  2.00    2    3    3.5     2.0      3.0
# Budlight                3    2.0  3.00    4    4    2.0     2.0      3.0
# Coors (Banquet)         2    3.0  2.50    3    2    1.5     3.5      3.5
# Red Stripe              3    1.5  3.00    3    2    3.0     1.0      1.0
# Corona                  1    1.0  1.50    1    1    1.0     1.0      1.0
# Modelo                  1    2.5  2.00    2    2    4.0     2.0      2.0
# Narragansett            5    3.5  1.00    3    2    4.0     2.5      3.0
# Miller Lite             3    2.0  3.50    1    3    2.9     1.0      3.5
# Natty Boh               2    3.0  2.50    1    2    1.0     2.0      4.0
# Rolling Rock            4    2.5  3.50    4    3    3.0     2.5      3.0
# Coors Light             3    1.5  4.50    3    3    3.5     3.0      2.0
# Heineken                1    2.5  2.75    2    2    4.0     1.0      2.0
#
#                   Rachel  Roberto  Tyler
# Beer
# Budweiser              2      2.0    4.0
# PBR                    1      3.0    3.5
# Ichiban                2      1.0    1.8
# Miller High Life       3      4.0    4.0
# Dos Equis              2      4.5    4.5
# Yuengling              4      2.5    4.8
# Natural Light          3      2.5    2.0
# Budlight               3      3.5    4.5
# Coors (Banquet)        4      3.5    3.5
# Red Stripe             1      1.0    4.9
# Corona                 1      3.0    1.0
# Modelo                 3      3.0    2.5
# Narragansett           3      3.5    3.0
# Miller Lite            2      2.5    1.5
# Natty Boh              3      3.0    2.0
# Rolling Rock           4      1.0    3.0
# Coors Light            3      1.5    4.0
# Heineken               3      1.0    2.0

# %%
beer.index
# Out:
# Index(['Budweiser', 'PBR', 'Ichiban', 'Miller High Life', 'Dos Equis',
#        'Yuengling', 'Natural Light', 'Budlight', 'Coors (Banquet)',
#        'Red Stripe', 'Corona', 'Modelo', 'Narragansett', 'Miller Lite',
#        'Natty Boh', 'Rolling Rock', 'Coors Light', 'Heineken'],
#       dtype='object', name='Beer')

# %%
test = beer.T.reset_index()

# %%
test
# Out:
# Beer        index Budweiser   PBR Ichiban Miller High Life Dos Equis  \
# 0     Beer Letter         A    B        C                D         E
# 1             Ali         3     2       2                1         2
# 2            Alec         4     3       1                1         1
# 3            Cara         2     4       4                3         5
# 4          Claire       4.1     3     1.8              2.5       3.8
# 5            Dave         2     3       2                2         4
# 6          Elaine       3.5     2       1              2.5       1.5
# 7           Emily         4     2       1                3       3.5
# 8         Heather         3     2       2                2         4
# 9           Jenna       3.5     3       3                3         4
# 10             Jo       2.5  2.75       2                3         4
# 11            Joe         3     3       2                4         2
# 12            Jon         3     2       1                3         2
# 13          Jules       1.3   4.5       3              3.5       4.8
# 14         Matt D         3     1     3.5                2         3
# 15        Miranda       3.5     2       3                4         4
# 16         Rachel         2     1       2                3         2
# 17        Roberto         2     3       1                4       4.5
# 18          Tyler         4   3.5     1.8                4       4.5
#
# Beer Yuengling Natural Light Budlight Coors (Banquet) Red Stripe Corona  \
# 0            F             G        H               I          J      K
# 1            4             3        1               2          1      3
# 2            5             1        2               3          3      1
# 3            4             2        2               2          1      2
# 4            1           2.2      3.8             3.8        2.4      3
# 5            4             3        1               3          2      1
# 6            4             3        2               4          1    1.5
# 7          3.5             3        3               4          1    1.5
# 8            5             2        3               2          3      1
# 9            2           1.5        2               3        1.5      1
# 10         4.7             2        3             2.5          3    1.5
# 11           4             2        4               3          3      1
# 12           4             3        4               2          2      1
# 13           5           3.5        2             1.5          3      1
# 14           3             2        2             3.5          1      1
# 15         4.5             3        3             3.5          1      1
# 16           4             3        3               4          1      1
# 17         2.5           2.5      3.5             3.5          1      3
# 18         4.8             2      4.5             3.5        4.9      1
#
# Beer Modelo Narragansett Miller Lite Natty Boh Rolling Rock Coors Light  \
# 0         L            M           N         O            P           Q
# 1         1            3           1         3            3           2
# 2         1            4           1         1            2           2
# 3         1            4           2         3            2           3
# 4       2.2          3.7         3.1       2.5            4         4.3
# 5         2            4           3         3            3           2
# 6         3          1.5           2         2            3         3.5
# 7         2          2.5           3       3.5            3           3
# 8         1            5           3         2            4           3
# 9       2.5          3.5           2         3          2.5         1.5
# 10        2            1         3.5       2.5          3.5         4.5
# 11        2            3           1         1            4           3
# 12        2            2           3         2            3           3
# 13        4            4         2.9         1            3         3.5
# 14        2          2.5           1         2          2.5           3
# 15        2            3         3.5         4            3           2
# 16        3            3           2         3            4           3
# 17        3          3.5         2.5         3            1         1.5
# 18      2.5            3         1.5         2            3           4
#
# Beer Heineken
# 0           R
# 1           2
# 2           4
# 3           4
# 4         1.1
# 5           2
# 6           2
# 7           2
# 8           1
# 9         2.5
# 10       2.75
# 11          2
# 12          2
# 13          4
# 14          1
# 15          2
# 16          3
# 17          1
# 18          2

# %%
test = test.drop(index=0)

# %%
sns.boxplot(data=test)
