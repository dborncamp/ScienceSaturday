# %% [markdown]
# # Look At Initial Beer things

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set(rc={'figure.figsize':(10,8)})

# %%
scoresdf = pd.read_csv("../data/SS2_beerScores.csv")

# %%
scoresdf.head()
# Out:
#                Beer Beer Letter  Ali  Alec  Cara  Claire  Dave  Elaine  Emily  \
# 0         Budweiser           A    3     4     2     4.1     2     3.5    4.0
# 1               PBR          B     2     3     4     3.0     3     2.0    2.0
# 2           Ichiban           C    2     1     4     1.8     2     1.0    1.0
# 3  Miller High Life           D    1     1     3     2.5     2     2.5    3.0
# 4         Dos Equis           E    2     1     5     3.8     4     1.5    3.5
#
#    Heather  Jenna    Jo  Joe  Jon  Jules  Matt D  Miranda  Rachel  Roberto  \
# 0        3    3.5  2.50    3    3    1.3     3.0      3.5       2      2.0
# 1        2    3.0  2.75    3    2    4.5     1.0      2.0       1      3.0
# 2        2    3.0  2.00    2    1    3.0     3.5      3.0       2      1.0
# 3        2    3.0  3.00    4    3    3.5     2.0      4.0       3      4.0
# 4        4    4.0  4.00    2    2    4.8     3.0      4.0       2      4.5
#
#    Tyler
# 0    4.0
# 1    3.5
# 2    1.8
# ...

# %%
scoresdf.T
# Out:
#                     0     1        2                 3          4          5   \
# Beer         Budweiser   PBR  Ichiban  Miller High Life  Dos Equis  Yuengling
# Beer Letter          A    B         C                 D          E          F
# Ali                  3     2        2                 1          2          4
# Alec                 4     3        1                 1          1          5
# Cara                 2     4        4                 3          5          4
# Claire             4.1     3      1.8               2.5        3.8          1
# Dave                 2     3        2                 2          4          4
# Elaine             3.5     2        1               2.5        1.5          4
# Emily                4     2        1                 3        3.5        3.5
# Heather              3     2        2                 2          4          5
# Jenna              3.5     3        3                 3          4          2
# ...

# %%
scoresdf.index
# Out:
# RangeIndex(start=0, stop=18, step=1)

# %%
plt.figure(figsize=(15,8))
sns.boxplot(data=scoresdf)

# %% [markdown]
# Looks like some people had a very high scatter in ratings

# %% [markdown]
# How about for each beer?

# %%
scoresdf.set_index("Beer")
# Out:
#                  Beer Letter  Ali  Alec  Cara  Claire  Dave  Elaine  Emily  \
# Beer
# Budweiser                  A    3     4     2     4.1     2     3.5    4.0
# PBR                       B     2     3     4     3.0     3     2.0    2.0
# Ichiban                    C    2     1     4     1.8     2     1.0    1.0
# Miller High Life           D    1     1     3     2.5     2     2.5    3.0
# Dos Equis                  E    2     1     5     3.8     4     1.5    3.5
# Yuengling                  F    4     5     4     1.0     4     4.0    3.5
# Natural Light              G    3     1     2     2.2     3     3.0    3.0
# Budlight                   H    1     2     2     3.8     1     2.0    3.0
# Coors (Banquet)            I    2     3     2     3.8     3     4.0    4.0
# Red Stripe                 J    1     3     1     2.4     2     1.0    1.0
# Corona                     K    3     1     2     3.0     1     1.5    1.5
# ...

# %%
beer = scoresdf.set_index("Beer")

# %%
beer
# Out:
#                  Beer Letter  Ali  Alec  Cara  Claire  Dave  Elaine  Emily  \
# Beer
# Budweiser                  A    3     4     2     4.1     2     3.5    4.0
# PBR                       B     2     3     4     3.0     3     2.0    2.0
# Ichiban                    C    2     1     4     1.8     2     1.0    1.0
# Miller High Life           D    1     1     3     2.5     2     2.5    3.0
# Dos Equis                  E    2     1     5     3.8     4     1.5    3.5
# Yuengling                  F    4     5     4     1.0     4     4.0    3.5
# Natural Light              G    3     1     2     2.2     3     3.0    3.0
# Budlight                   H    1     2     2     3.8     1     2.0    3.0
# Coors (Banquet)            I    2     3     2     3.8     3     4.0    4.0
# Red Stripe                 J    1     3     1     2.4     2     1.0    1.0
# Corona                     K    3     1     2     3.0     1     1.5    1.5
# ...

# %%
beer = beer.T.reset_index()

# %%
beer = beer.drop(index=0)  # take out the letters

# %%
fig = plt.figure(figsize=(20,8))
ax = sns.boxplot(data=beer)

# %%
fig.savefig("../tex/beerResults.pdf")

# %%
beer
# Out:
# Beer    index Budweiser   PBR Ichiban Miller High Life Dos Equis Yuengling  \
# 1         Ali         3     2       2                1         2         4
# 2        Alec         4     3       1                1         1         5
# 3        Cara         2     4       4                3         5         4
# 4      Claire       4.1     3     1.8              2.5       3.8         1
# 5        Dave         2     3       2                2         4         4
# 6      Elaine       3.5     2       1              2.5       1.5         4
# 7       Emily         4     2       1                3       3.5       3.5
# 8     Heather         3     2       2                2         4         5
# 9       Jenna       3.5     3       3                3         4         2
# 10         Jo       2.5  2.75       2                3         4       4.7
# 11        Joe         3     3       2                4         2         4
# ...

# %%
print(beer.to_latex())
# Out:
# \begin{tabular}{llllllllllllllllllll}
# \toprule
# Beer &    index & Budweiser &   PBR & Ichiban & Miller High Life & Dos Equis & Yuengling & Natural Light & Budlight & Coors (Banquet) & Red Stripe & Corona & Modelo & Narragansett & Miller Lite & Natty Boh & Rolling Rock & Coors Light & Heineken \\
# \midrule
# 1  &      Ali &         3 &     2 &       2 &                1 &         2 &         4 &             3 &        1 &               2 &          1 &      3 &      1 &            3 &           1 &         3 &            3 &           2 &        2 \\
# 2  &     Alec &         4 &     3 &       1 &                1 &         1 &         5 &             1 &        2 &               3 &          3 &      1 &      1 &            4 &           1 &         1 &            2 &           2 &        4 \\
# ...
